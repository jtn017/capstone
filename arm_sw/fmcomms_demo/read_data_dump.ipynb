# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
fid = open("./iio_stream/build/fmcomms_data.dat","rb")
data = np.fromfile(fid,dtype='int16')

# %%
head = 20000
plot_len = 110000
tail = head + plot_len

inphase = data[head:tail:2]
quadrature = data[head+1:tail:2]

# %%
plt.plot(inphase)
plt.plot(quadrature)
plt.show()

# %%
data = 0
inphase = 0
quadrature = 0

# %%
data.size
# Out:
# 5324288
